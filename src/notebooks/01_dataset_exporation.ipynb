# %%
# %load_ext autoreload
# %autoreload 2

import meles

# %%
# 1. Download the dataset recipe
# 2. Download the dataset
# 3. Integrate the dataset into our schema

# TODO maybe replace the recognizer with DeepFace (https://github.com/serengil/deepface) and focus more on the aggregation methods? It already supports VGG-Face, Facenet, Facenet512, OpenFace, DeepFace, DeepID, Dlib, ArcFace, SFace and GhostFaceNet
