# %%
# %load_ext autoreload
# %autoreload 2

import meles

# %% [markdown]
# **Meles** uses pytorch, as such, it is recommended to have a CUDA-enabled GPU to run the code.

# %%
import torch

torch.cuda.is_available()
# Out:
# True
